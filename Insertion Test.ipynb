# %%
import Seasons

# %%
Season11 = Seasons.Season(2011, ["D1","D2"]);
# Out:
# Connection to database.sqlite successfull. with curser <sqlite3.Cursor object at 0x1a203560a0>
# Created Game: 1491
# Created Game: 1094
# Created Game: 1211
# Created Game: 1104
# Created Game: 1197
# Created Game: 1100
# Created Game: 1262
# Created Game: 1102
# Created Game: 1401
# Created Game: 1101
# Created Game: 1293
# Created Game: 1106
# Created Game: 1122
# Created Game: 1095
# Created Game: 1335
# Created Game: 1093
# Created Game: 1178
# Created Game: 1097
# Created Game: 1481
# Created Game: 1098
# Created Game: 1235
# Created Game: 1096
# Created Game: 1310
# Created Game: 1103
# Created Game: 1643
# Created Game: 1105
# Created Game: 1364
# Created Game: 1092
# Created Game: 1623
# Created Game: 1108
# Created Game: 1428
# Created Game: 1099
# Created Game: 1324
# Created Game: 1107
# Created Game: 1219
# Created Game: 1113
# Created Game: 1295
# Created Game: 1109
# Created Game: 1407
# Created Game: 1118
# Created Game: 1124
# Created Game: 1634
# Created Game: 1123
# ...

# %%
Teams_dict = [team.__dict__ for team in Season11.teams_list]

# %%
Teams_dict[0]
# Out:
# {'id': 0,
#  'name': 'Bayern Munich',
#  'goal_counter': 154,
#  'win_counter': 46,
#  'loss_counter': 14,
#  'tie_counter': 8,
#  'winning_percentage': 0.6764705882352942,
#  'stadium_location': 'undefined',
#  'num_of_games_played': 68}
